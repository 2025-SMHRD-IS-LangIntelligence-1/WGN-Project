# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\smhrd\anaconda3\lib\site-packages (1.1.1)

# %%
import pymysql # DB 연결
from io import BytesIO  # 메모리 버퍼를 사용하기 위한 모듈
from wordcloud import WordCloud  # 워드클라우드 생성 라이브러리
from typing import List # 리스트 타이핑
import base64  # 바이너리 데이터를 base64 문자열로 인코딩하는 모듈
import pandas as pd 

# DB 연결 설정
conn = pymysql.connect(
    host='project-db-cgi.smhrd.com',
    port=3307,
    user='CGI_25IS_LI_P2_3',
    password='smhrd3',
    db='CGI_25IS_LI_P2_3',
    charset='utf8mb4'
)

# %%
# 쿼리 작성
query = """
                SELECT
                    f.feed_idx,
                    f.feed_likes,
                    r.res_tag,
                    f.feed_content
                FROM
                    t_feed f
                LEFT JOIN
                    t_restaurant r ON r.res_idx = f.res_idx
                """

# 쿼리 실행 후 데이터프레임으로 변환
df = pd.read_sql(query, conn)
# Out:
# C:\Users\smhrd\AppData\Local\Temp\ipykernel_13656\2187754842.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1198 try:
# -> 1199     first_packet = self.connection._read_packet()
#    1201     if first_packet.is_ok_packet():
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:753, in Connection._read_packet(self, packet_type)
#     751 if packet_number == 0:
#     752     # MariaDB sends error packet with seqno==0 when shutdown
# --> 753     raise err.OperationalError(
#     754         CR.CR_SERVER_LOST,
#     755         "Lost connection to MySQL server during query",
#     756     )
#     757 raise err.InternalError(
#     758     "Packet sequence number wrong - got %d expected %d"
#     759     % (packet_number, self._next_seq_id)
#     760 )
#
# OperationalError: (2013, 'Lost connection to MySQL server during query')
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2678, in SQLiteDatabase.execute(self, sql, params)
#    2677 try:
# -> 2678     self.con.rollback()
#    2679 except Exception as inner_exc:  # pragma: no cover
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:492, in Connection.rollback(self)
#     486 """
#     487 Roll back the current transaction.
#     488
#     489 See `Connection.rollback() <https://www.python.org/dev/peps/pep-0249/#rollback>`_
#     490 in the specification.
#     491 """
# --> 492 self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#     493 self._read_ok_packet()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:843, in Connection._execute_command(self, command, sql)
#     842 if not self._sock:
# --> 843     raise err.InterfaceError(0, "")
#     845 # If the last query was unbuffered, make sure it finishes before
#     846 # sending new commands
#
# InterfaceError: (0, '')
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[35], line 15
#       2 query = """
#       3                 SELECT
#       4                     f.feed_idx,
#    (...)
#      11                     t_restaurant r ON r.res_idx = f.res_idx
#      12                 """
#      14 # 쿼리 실행 후 데이터프레임으로 변환
# ---> 15 df = pd.read_sql(query, conn)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)
#    2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2683, in SQLiteDatabase.execute(self, sql, params)
#    2679 except Exception as inner_exc:  # pragma: no cover
#    2680     ex = DatabaseError(
#    2681         f"Execution failed on sql: {sql}\n{exc}\nunable to rollback"
#    2682     )
# -> 2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
#    2686 raise ex from exc
#
# DatabaseError: Execution failed on sql:
#                 SELECT
#                     f.feed_idx,
#                     f.feed_likes,
#                     r.res_tag,
#                     f.feed_content
#                 FROM
#                     t_feed f
#                 LEFT JOIN
#                     t_restaurant r ON r.res_idx = f.res_idx
#
# (2013, 'Lost connection to MySQL server during query')
# unable to rollback

# %%
df
# Out:
#      feed_idx  feed_likes              res_tag  \
# 0          46           3           바비큐 불고기 파이
# 1          51           1                파이 라멘
# 2          56           0           바비큐 불고기 파이
# 3          57           0          냉면 삼겹살 목살 회
# 4          58           0         청국장 쌈밥 토종닭 회
# ..        ...         ...                  ...
# 104       301           0  파이 불고기 햄버거 커피 아메리카노
# 105       302           0         마라탕 마라샹궈 볶음밥
# 106       303           0      마라탕 마라샹궈 볶음밥 파이
# 107       304           0          마라탕 홍차 마라샹궈
# 108       306           2                 태그없음
#
#                          feed_content
# 0                        버거킹 광주봉선점ㄹㅇㅎ
# 1                                쿠로시로
# 2                          버거킹 전남대후문점
# 3                          목구멍 광주ㅁ충장점
# 4                              뜨락의아침ㅁ
# ..                                ...
# 104                맛집\r\n#맥도날드 전남대DT점
# 105                 ㅁㄴㅇㄹ\r\n#마라미녀 전대점
# 106              맛집입니다\r\n#소림마라 광주동구점
# 107          asfdasdf\r\n#이런이궈마라탕 진월점
# 108  맛있는 거 먹고 싶당\r\n#500도참숯불맛삼겹살 신안동점
#
# [109 rows x 4 columns]

# %%
def text_to_base64_wordcloud(text: str) -> str:
    # 입력받은 텍스트로 워드클라우드 이미지를 생성하여
    # PNG 포맷으로 메모리 버퍼에 저장한 후
    # Base64 문자열로 변환해 반환하는 함수

    print("=== text_to_base64_wordcloud 함수 실행 ===")
    
    wc = WordCloud(
        width=400, height=400, background_color="white", 
        font_path="malgun.ttf"  # 한글 폰트 경로
    )
    
    wc.generate(text)  # 워드클라우드 이미지 생성

    buffer = BytesIO()  # 메모리 버퍼 생성
    wc.to_image().save(buffer, format="PNG")  # 워드클라우드 이미지를 PNG로 버퍼에 저장

    img_str = base64.b64encode(buffer.getvalue()).decode()  
    # 버퍼의 바이너리 데이터를 base64 문자열로 인코딩 후 디코딩하여 str로 변환

    print("=== text_to_base64_wordcloud 함수 종료 ===")
    
    return img_str  # Base64로 인코딩된 워드클라우드 이미지 문자열 반환

# %%
def make_wordclouds(review_list: List[Review]) -> Wordcloud:

    print("=== make_wordclouds 함수 실행 ===")

    print("=== make_wordclouds 함수 종료 ===")    
    
    return Wordcloud(
        NkPositiveWC=text_to_base64_wordcloud(), # 여기에 워드클라우드 이미지 문자열 넣을 것
        NkNegativeWC=text_to_base64_wordcloud(),
        WgnPositiveWC=text_to_base64_wordcloud(),
        WgnNegativeWC=text_to_base64_wordcloud(),
    )
